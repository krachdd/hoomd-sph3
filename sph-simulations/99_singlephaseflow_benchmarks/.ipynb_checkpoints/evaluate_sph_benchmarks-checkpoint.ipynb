# %% [markdown]
# # Evaluate standart benchmarks
#
# Benchmarks Single-Phase Flow
#
# - Poiseuille flow in a tube
# - Flow between parallel plates
# - Couette flow

# %%
## HEADER ## 
import numpy as np
import os, sys, glob
import matplotlib.pyplot as plt

# %%
# Import daves_py_modules to handle .vtu files
sys.path.append('/scratch/local1/krach/data/00_processing/daves_py_modules/')
sys.path.append('/home/david/Arbeit/data/00_processing/daves_py_modules/')
import readwrite

# %% [markdown]
# ## Poiseuille Flow
# Convergence, discretisation, analytical solution

# %%
simulations_res = [
                20, 
                30, 
                50, 
                100
]

path_poiseuille = '01_poiseuille'
logfiles_poiseuille = [
    'poiseuille_flow_20_28_28_vs_0.005_run.log',
    'poiseuille_flow_30_38_38_vs_0.0033333333333333335_run.log',
    'poiseuille_flow_50_58_58_vs_0.002_run.log',
    'poiseuille_flow_100_108_108_vs_0.001_run.log'
]

for i in range(len(simulations_res)):
    conv_data = np.genfromtxt(f'{path_poiseuille}/{logfiles_poiseuille[i]}', skip_header = 1)[:, -2]
    number_fparticles = np.genfromtxt(f'{path_poiseuille}/{logfiles_poiseuille[i]}', skip_header = 1)[-1, -3]
    norm_conv_data = np.divide(conv_data, number_fparticles)
    plt.plot(norm_conv_data, label = f'{simulations_res[i]}')
    plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2671510/3020966747.py in <module>
#      15
#      16 for i in range(len(simulations_res)):
# ---> 17     conv_data = np.genfromtxt(f'{path_poiseuille}/{logfiles_poiseuille[i]}', skip_header = 1)[:, -2]
#      18     number_fparticles = np.genfromtxt(f'{path_poiseuille}/{logfiles_poiseuille[i]}', skip_header = 1)[-1, -3]
#      19     norm_conv_data = np.divide(conv_data, number_fparticles)
#
# ~/software/anaconda3/envs/datahandling_ploting/lib/python3.10/site-packages/numpy/lib/npyio.py in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1957         fname = os_fspath(fname)
#    1958     if isinstance(fname, str):
# -> 1959         fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1960         fid_ctx = contextlib.closing(fid)
#    1961     else:
#
# ~/software/anaconda3/envs/datahandling_ploting/lib/python3.10/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     191
#     192     ds = DataSource(destpath)
# --> 193     return ds.open(path, mode, encoding=encoding, newline=newline)
#     194
#     195
#
# ~/software/anaconda3/envs/datahandling_ploting/lib/python3.10/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     531                                       encoding=encoding, newline=newline)
#     532         else:
# --> 533             raise FileNotFoundError(f"{path} not found.")
#     534
#     535
#
# FileNotFoundError: 01_poiseuille/poiseuille_flow_30_38_38_vs_0.0033333333333333335_run.log not found.

# %% [markdown]
# ## Parallel Plates
# Convergence, discretisation and analytical solution

# %%
simulations_res = [
                    20, 
                    30, 
                    50, 
                    100
]

path_plates = '02_parallel_plates'
logfiles_plates = [
    'parallel_plates_20_28_17_vs_0.005_run.log',
    'parallel_plates_30_38_17_vs_0.0033333333333333335_run.log',
    'parallel_plates_50_58_17_vs_0.002_run.log',
    'parallel_plates_100_108_17_vs_0.001_run.log'
]

for i in range(len(simulations_res)):
    conv_data = np.genfromtxt(f'{path_plates}/{logfiles_plates[i]}', skip_header = 1)[:, -2]
    number_fparticles = np.genfromtxt(f'{path_plates}/{logfiles_plates[i]}', skip_header = 1)[-1, -3]
    norm_conv_data = np.divide(conv_data, number_fparticles)
    plt.plot(norm_conv_data, label = f'{simulations_res[i]}')
    plt.legend()
plt.show()

# %% [markdown]
# ## Couette Flow
# Convergence, discretisation, and analytical solution
